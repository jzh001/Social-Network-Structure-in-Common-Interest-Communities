# %%
import numpy as np
import pandas as pd
import networkx as nx
import collections as clt
import matplotlib.pyplot as plt
import pickle
from concepts import Context

# %%
plt.rcParams["figure.figsize"] = (10,7) #defining size of plots

# %%
df = pd.read_csv('reviews_full_v7.csv')
df.head(5)
# Out:
#                User          Date  Year  Month  \
# 0  SpookyApparition  July 11 2002  2002      7
# 1  SpookyApparition  July 14 2002  2002      7
# 2          MarkRyan  July 15 2002  2002      7
# 3              Fear  July 16 2002  2002      7
# 4          Esoteric  July 16 2002  2002      7
#
#                                      Release            Band  Score  \
# 0                                 Chaosphere       Meshuggah     82
# 1  Necroticism_-_Descanting_the_Insalubrious         Carcass     88
# 2                          Angels_Fall_First       Nightwish     90
# 3                               Dark_Genesis      Iced_Earth     87
# 4                       A_Night_at_the_Opera  Blind_Guardian     70
#
#                                                 Link  \
# 0  https://www.metal-archives.com/reviews/Meshugg...
# 1  https://www.metal-archives.com/reviews/Carcass...
# 2  https://www.metal-archives.com/reviews/Nightwi...
# 3  https://www.metal-archives.com/reviews/Iced_Ea...
# 4  https://www.metal-archives.com/reviews/Blind_G...
#
#                                           Album_link  \
# 0  https://www.metal-archives.com/albums/Meshugga...
# 1  https://www.metal-archives.com/albums/Carcass/...
# 2  https://www.metal-archives.com/albums/Nightwis...
# 3  https://www.metal-archives.com/albums/Iced_Ear...
# 4  https://www.metal-archives.com/albums/Blind_Gu...
#
#                        Review_title  \
# 0   Technical metal at it's finest.
# 1          Carcass at their finest.
# 2  On par with their other stuff...
# 3         Brilliance in Repackaging
# 4            Somewhat Disappointing
#
#                                                Genre  \
# 0  technical thrash metal|math metal|progressive ...
# 1                      grindcore|melodic death metal
# 2                              symphonic power metal
# 3                         heavy metal|us power metal
# 4                                        power metal
#
#                                                 Text  Sentiment  \
# 0  I originally bought Chaosphere in late 2000......     0.9728
# 1  A midpoint between Carcass' early grind albums...     0.8479
# 2  I'm not hard-core into metal at all, really, b...     0.9951
# 3  This is not a new album, but in fact, five alb...     0.9976
# 4  I've been trying for months to come up with an...     0.5494
#
#                     Band_Genre  \
# 0    groove metal|thrash metal
# 1        grindcore|death metal
# 2  symphonic metal|power metal
# 3     thrash metal|power metal
# 4      speed metal|power metal
#
#                                       Combined_Genre
# 0  technical thrash metal|math metal|progressive ...
# 1                      grindcore|melodic death metal
# 2                              symphonic power metal
# 3                         heavy metal|us power metal
# 4                                        power metal

# %%
def isNan(x):
    return x != x

# %%
B = nx.Graph()
mp = clt.Counter(df['User'])
posScore = 75
albums = set()
users = set()
genres = set()
user_list = []
for i,row in df.iterrows():
    album = row['Release'] + 'A' #to differentiate
    user = row['User']
    if row['Score'] >= posScore and mp[user] > 2:
        albums.add(album)
        users.add(user)
        user_list.append(user)
        #B.add_edge(album,user)
        if isNan(row['Combined_Genre']):
            continue
        for genre in row['Combined_Genre'].split('|'):
            genres.add(genre)
            if not B.has_edge(user,genre):
                B.add_edge(user,genre, weight = 1)
            else:
                B[user][genre]['weight'] += 1

# %%
plt.semilogy(sorted(list(nx.get_edge_attributes(B,'weight').values())))

# %%
B = nx.Graph(B)
for u,v in B.edges():
    if B[u][v]['weight'] < 4:
        B.remove_edge(u,v)
    
genre_group = pickle.load(open('genre_group.p','rb'))
print(len(genres))

for genre in genres.copy():
    #if node not in genre_group:
        #print(node)
    if genre not in genre_group or genre_group[genre] == 'Non-metal' or genre_group[genre] == 'Others':
        B.remove_node(genre)
        genres.remove(genre)


B = B.subgraph(sorted([(len(cc),cc) for cc in nx.connected_components(B)])[-1][1])
for user in users.copy():
    if not B.has_node(user):
        users.remove(user)
'''for album in albums.copy():
    if not B.has_node(album):
        albums.remove(album)'''
for genre in genres.copy():
    if not B.has_node(genre):
        genres.remove(genre)
# Out:
# 284

# %%
B.number_of_nodes(), B.number_of_edges(), nx.number_connected_components(B), len(genres), len(users)
# Out:
# (1174, 3057, 1, 91, 1083)

# %% [raw]
# def getAdjSet(nodes):
#     ret = set()
#     for node in nodes:
#         ret.update(B.adj[node])
#     return ret
#
# def combine(groups):
#     ret = set(users.copy())
#     #print(groups[0])
#     for grp in groups:
#         ret = ret.intersection(grp)
#         #print(grp)
#
#     return ret

# %% [raw]
# for genre in genres:
#     userSet = getAdjSet([genre])
#     #genreSet = getAdjSet(userSet)
#     #userSet = getAdjSet(genreSet)
#     #genreSet = getAdjSet(userSet)
#     #userSet = combine([list(B.adj[genre]) for genre in genreSet])
#     genreSet = combine([list(B.adj[user]) for user in userSet])
#     break
# #print(genreSet)
# #print(userSet)
# print(len(userSet),len(genreSet))

# %%
context_df = pd.DataFrame()
contexts = {}
for u,v in B.edges:
    if u not in genres:
        u,v = v,u
    contexts[(u,v)] = B[u][v]['weight']


print(clt.Counter(contexts.values()))

genres = list(genres)
users = list(users)

for genre in genres:
    arr = []
    for user in users:
        if (genre,user) in contexts:
            arr.append('X')
        else:
            arr.append('')
    context_df[genre] = arr

context_df.index = users
context_df.to_csv('contexts_fca.csv')
#context_df.to_csv('contexts_fca.csv')
context_df
# Out:
# Counter({4: 817, 5: 517, 6: 329, 7: 233, 8: 182, 9: 140, 11: 96, 10: 95, 12: 76, 13: 53, 14: 52, 15: 49, 16: 44, 17: 25, 21: 24, 19: 22, 22: 21, 18: 19, 20: 15, 23: 15, 24: 14, 26: 13, 25: 13, 31: 11, 27: 10, 29: 8, 34: 8, 36: 8, 35: 8, 28: 8, 37: 8, 30: 7, 32: 6, 43: 6, 45: 5, 40: 5, 42: 5, 33: 5, 63: 4, 44: 4, 126: 3, 46: 3, 53: 3, 71: 3, 39: 3, 38: 3, 57: 2, 56: 2, 54: 2, 69: 2, 41: 2, 68: 2, 111: 2, 47: 2, 55: 2, 59: 2, 95: 1, 87: 1, 139: 1, 49: 1, 77: 1, 88: 1, 191: 1, 58: 1, 51: 1, 148: 1, 395: 1, 383: 1, 223: 1, 70: 1, 377: 1, 52: 1, 83: 1, 115: 1, 91: 1, 99: 1, 246: 1, 461: 1, 65: 1, 67: 1, 135: 1, 104: 1, 105: 1, 349: 1, 363: 1, 136: 1, 66: 1, 89: 1, 110: 1, 145: 1, 128: 1, 151: 1, 164: 1, 144: 1, 48: 1})
#                 technical thrash metal progressive hard rock  \
# mjollnir
# Autumn_aurorA
# ozzeh
# marienbad
# Oscar1989
# ...                                ...                   ...
# lord_weballergy
# dalecooper
# Roswell47
# nightzblood
# Tzeench
#
#                 melodic power metal blackened folk metal melodic metalcore  \
# mjollnir
# Autumn_aurorA
# ozzeh
# marienbad
# Oscar1989
# ...                             ...                  ...               ...
# lord_weballergy
# dalecooper
# Roswell47
# nightzblood
# Tzeench
#
#                 black doom metal progressive power metal  \
# mjollnir
# Autumn_aurorA
# ozzeh
# marienbad
# Oscar1989
# ...                          ...                     ...
# lord_weballergy
# dalecooper
# Roswell47
# nightzblood
# Tzeench
#
#                 electro industrial metal blackened speed metal  \
# mjollnir
# Autumn_aurorA
# ozzeh
# marienbad
# Oscar1989
# ...                                  ...                   ...
# lord_weballergy
# dalecooper
# Roswell47
# nightzblood
# Tzeench
#
#                 atmospheric black metal  ... blackened thrash metal  \
# mjollnir                                 ...
# Autumn_aurorA                            ...
# ozzeh                                    ...
# marienbad                                ...
# Oscar1989                                ...
# ...                                 ...  ...                    ...
# lord_weballergy                          ...
# dalecooper                               ...
# Roswell47                                ...
# nightzblood                              ...
# Tzeench                                  ...
#
#                 bay area thrash metal blackened doom metal  \
# mjollnir
# Autumn_aurorA
# ozzeh
# marienbad
# Oscar1989
# ...                               ...                  ...
# lord_weballergy
# dalecooper
# Roswell47
# nightzblood
# Tzeench
#
#                 industrial death metal symphonic doom metal  \
# mjollnir
# Autumn_aurorA
# ozzeh
# marienbad
# Oscar1989
# ...                                ...                  ...
# lord_weballergy
# dalecooper
# Roswell47
# nightzblood
# Tzeench
#
#                 progressive black metal melodic death metal  \
# mjollnir                              X                   X
# Autumn_aurorA
# ozzeh                                                     X
# marienbad
# Oscar1989
# ...                                 ...                 ...
# lord_weballergy
# dalecooper
# Roswell47
# nightzblood
# Tzeench
#
#                 teutonic thrash metal folk metal psychedelic doom metal
# mjollnir                                       X
# Autumn_aurorA
# ozzeh
# marienbad
# Oscar1989
# ...                               ...        ...                    ...
# lord_weballergy
# dalecooper
# Roswell47
# nightzblood
# Tzeench
#
# [1083 rows x 91 columns]

# %%
c = Context.fromfile('contexts_fca.csv', frmat = 'csv')
l = c.lattice

# %%
x, y = l[1000]
print(x,y)
# Out:
# ('autothrall', 'CHRISTI_NS_ANITY8', 'hells_unicorn', 'UltraBoris', 'Gutterscream', 'gasmask_colostomy') ('heavy metal', 'black metal', 'death metal', 'doom metal', 'power metal', 'thrash metal', 'teutonic thrash metal')

# %%
concept_list = [(x,y) for x,y in l]
pickle.dump(concept_list, open('concept_list.p','wb'))

# %%
f = open('concept_pairs.txt','w')
for x,y in concept_list:
    f.write(str(x) + '\n' + str(y) + '\n\n')
f.close()

# %%
len(set(df['User']))
# Out:
# 9317

# %%
len(genre_group)
# Out:
# 298
